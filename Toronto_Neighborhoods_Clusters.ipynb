# %% [markdown]
# # Toronto Neighborhoods Clusters
#
# Scrapes the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe.
#
# Adds the geographical coordinates of each postal code from: http://cocl.us/Geospatial_data
#
# Explores and clusters the neighborhoods in Toronto; generates a map to visualize your neighborhoods and how they cluster together.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

import requests
from urllib.request import urlopen

from geopy.geocoders import Nominatim 

import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

from sklearn.cluster import KMeans

def BeautifulTablesFromPage(article):

    from pandas import DataFrame
    from bs4 import BeautifulSoup
    
    soup = BeautifulSoup(article, 'html.parser')
    tables = soup.find_all('table', class_='sortable')
    
    all_tables_content = []
    for table in tables:
        ths = table.find_all('th')
        table_headings = [th.text.strip() for th in ths]
    
        table_content = []
        for tr in table.find_all('tr'):
            tds = tr.find_all('td')
            if not tds:
                continue
            table_content.append([td.text.strip() for td in tds])
        
        df = DataFrame(table_content)
        df.columns = table_headings
        all_tables_content.append(df)
        
        return(all_tables_content)

# %% [markdown]
# #### Scraping and Data Manipulation

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# save the file locally
with open('List_of_postal_codes_of_Canada:_M', 'w') as art: 
    art.write(urlopen(url).read().decode())

# Load article
article = open('List_of_postal_codes_of_Canada:_M').read()

all_tables = BeautifulTablesFromPage(article)

postal_codes_of_Canada = all_tables[0].copy()

#If Borough is Not assigned then drop line 
postal_codes_of_Canada = postal_codes_of_Canada[postal_codes_of_Canada['Borough'] != 'Not assigned']
postal_codes_of_Canada.reset_index(drop=True,inplace=True)

#If Neighbourhood is Not assigned then replace it with Borough
for i, row in postal_codes_of_Canada.iterrows():
    if row['Neighbourhood'] == 'Not assigned':
        postal_codes_of_Canada.loc[i]['Neighbourhood'] = row['Borough']

# %% [markdown]
# #### Imports Geospatial Coordinate data

# %%
Geospatial_Coordinates = pd.read_csv('https://cocl.us/Geospatial_data')
target_locations = postal_codes_of_Canada.set_index('Postal Code').merge(Geospatial_Coordinates.set_index('Postal Code'), on='Postal Code')
target_locations.reset_index(inplace=True)

# %% [markdown]
# #### Neighborhoods Dataframe

# %%
# Filtering Toronto Locations
target_locations = target_locations[target_locations['Borough'].apply(lambda x: x.find('Toronto')) > 0]

target_locations.head()
# Out:
#    Postal Code           Borough                                Neighbourhood  \
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 9          M5B  Downtown Toronto                     Garden District, Ryerson
# 15         M5C  Downtown Toronto                               St. James Town
# 19         M4E      East Toronto                                  The Beaches
#
#      Latitude  Longitude
# 2   43.654260 -79.360636
# 4   43.662301 -79.389494
# 9   43.657162 -79.378937
# 15  43.651494 -79.375418
# 19  43.676357 -79.293031

# %% [markdown]
# ## Foursquare API
# ### Get neighbourhoods venues
#
# Defines a function to get the venues for a Toronto neighbourhood using the Foursquare API.

# %%
# Foursquare credentials

param_authentication = {'CLIENT_ID':'[REMOVED]',
                        'CLIENT_SECRET':'[REMOVED]'
                        }

# %%
def GetSurroundings(p_authentication, p_coordinates, param_radius, param_limit):
    
    url = 'https://api.foursquare.com/v2/venues/explore'
    
    params = dict(  client_id = p_authentication['CLIENT_ID'],
                    client_secret = p_authentication['CLIENT_SECRET'],
                    v = '20180604',
                    limit = param_limit,            
                    ll = p_coordinates,
                    radius = param_radius)
    
    raw_results = requests.get(url=url, params=params).json()
    
    df_results = pd.json_normalize(raw_results['response']['groups'][0]['items'])
    df_results = df_results.loc[:, ['venue.name','venue.location.lat', 'venue.location.lng','venue.categories']]
    df_results['venue.categories'] = df_results['venue.categories'].apply(lambda x: None if len(x) == 0 else x[0]['name'])
    df_results.columns = ['Venue','Venue Latitude','Venue Longitude','Venue Category']
        
    return(df_results)

# %% [markdown]
# Uses the function in a loop to retrieve the venues for every Toronto neighbourhood and stores in a dataframe

# %%
nearby_venues = pd.DataFrame(columns = ['Venue',
                                        'Venue Latitude',
                                        'Venue Longitude',
                                        'Venue Category',
                                        'Borough',
                                        'Neighbourhood', 
                                        'Neighbourhood Latitude',
                                        'Neighbourhood Longitude'
                                        ])

for i, ith_neighbourhood in target_locations.iterrows():

    venues = GetSurroundings(p_authentication = param_authentication, 
                             p_coordinates = str(ith_neighbourhood['Latitude'])+', '+str(ith_neighbourhood['Longitude']), 
                             param_radius = 500, 
                             param_limit = 100)
    
    venues['Borough'] = ith_neighbourhood['Borough']
    venues['Neighbourhood'] = ith_neighbourhood['Neighbourhood']
    venues['Neighbourhood Latitude'] = ith_neighbourhood['Latitude']
    venues['Neighbourhood Longitude'] = ith_neighbourhood['Longitude']

    nearby_venues = nearby_venues.append(venues, ignore_index=True)

    del venues

# %% [markdown]
# Shows the number of venues retrieved for every Neighbourhood. The table shows how some areas have very few venues;
# all of those with less than 10 venues will be dropped and not used for the creation of the clusters

# %%
nearby_venues.groupby(['Neighbourhood'])['Venue'].count().sort_values()
# Out:
# Neighbourhood
# Moore Park, Summerhill East                                                                                     2
# Lawrence Park                                                                                                   3
# Roselawn                                                                                                        3
# The Beaches                                                                                                     4
# Rosedale                                                                                                        5
# Forest Hill North & West, Forest Hill Road Park                                                                 5
# Davisville North                                                                                                9
# Dufferin, Dovercourt Village                                                                                   13
# Parkdale, Roncesvalles                                                                                         14
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park                                              14
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto                           16
# Christie                                                                                                       16
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport     17
# North Toronto West,  Lawrence Park                                                                             18
# The Annex, North Midtown, Yorkville                                                                            19
# India Bazaar, The Beaches West                                                                                 19
# Brockton, Parkdale Village, Exhibition Place                                                                   25
# High Park, The Junction South                                                                                  26
# Queen's Park, Ontario Provincial Government                                                                    33
# University of Toronto, Harbord                                                                                 34
# Davisville                                                                                                     34
# Runnymede, Swansea                                                                                             35
# Studio District                                                                                                37
# The Danforth West, Riverdale                                                                                   44
# Regent Park, Harbourfront                                                                                      45
# Little Portugal, Trinity                                                                                       46
# St. James Town, Cabbagetown                                                                                    50
# Berczy Park                                                                                                    55
# Central Bay Street                                                                                             68
# Kensington Market, Chinatown, Grange Park                                                                      74
# Church and Wellesley                                                                                           75
# St. James Town                                                                                                 85
# Stn A PO Boxes                                                                                                 96
# Toronto Dominion Centre, Design Exchange                                                                      100
# Harbourfront East, Union Station, Toronto Islands                                                             100
# Garden District, Ryerson                                                                                      100
# First Canadian Place, Underground city                                                                        100
# Commerce Court, Victoria Hotel                                                                                100
# Richmond, Adelaide, King                                                                                      100
# Name: Venue, dtype: int64

# %%
few_venues_neigh = nearby_venues.groupby(['Neighbourhood'])['Venue'].count().sort_values()[0:7].index.values
nearby_venues = nearby_venues[~nearby_venues['Neighbourhood'].isin(few_venues_neigh)]

nearby_venues.head()
# Out:
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3          Impact Kitchen       43.656369       -79.356980
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category           Borough              Neighbourhood  \
# 0               Bakery  Downtown Toronto  Regent Park, Harbourfront
# 1          Coffee Shop  Downtown Toronto  Regent Park, Harbourfront
# 2  Distribution Center  Downtown Toronto  Regent Park, Harbourfront
# 3           Restaurant  Downtown Toronto  Regent Park, Harbourfront
# 4                  Spa  Downtown Toronto  Regent Park, Harbourfront
#
#    Neighbourhood Latitude  Neighbourhood Longitude
# 0                43.65426               -79.360636
# 1                43.65426               -79.360636
# 2                43.65426               -79.360636
# 3                43.65426               -79.360636
# 4                43.65426               -79.360636

# %% [markdown]
# Shows the frequency of distinct types of venue (Venue Category):

# %%
nearby_venues.groupby(['Venue Category'])['Venue'].count().sort_values(ascending=False)
# Out:
# Venue Category
# Coffee Shop                        159
# Café                                84
# Restaurant                          56
# Hotel                               39
# Italian Restaurant                  35
# Japanese Restaurant                 32
# Park                                31
# Bakery                              30
# Bar                                 29
# Pizza Place                         28
# Gym                                 26
# Sushi Restaurant                    24
# Sandwich Place                      23
# Seafood Restaurant                  22
# Pub                                 21
# Bookstore                           20
# American Restaurant                 20
# Beer Bar                            19
# Thai Restaurant                     19
# Clothing Store                      19
# Gastropub                           18
# Breakfast Spot                      16
# Vegetarian / Vegan Restaurant       16
# Diner                               15
# Grocery Store                       14
# Steakhouse                          13
# Dessert Shop                        13
# Brewery                             13
# Cocktail Bar                        13
# Art Gallery                         13
# Theater                             13
# Deli / Bodega                       12
# Mexican Restaurant                  12
# Salad Place                         12
# Greek Restaurant                    12
# Yoga Studio                         12
# Asian Restaurant                    11
# Fast Food Restaurant                11
# Farmers Market                      11
# Furniture / Home Store              11
# Department Store                    11
# Cosmetics Shop                      11
# Burrito Place                       10
# Burger Joint                        10
# French Restaurant                   10
# Wine Bar                            10
# Ice Cream Shop                      10
# Bank                                10
# Pharmacy                             9
# Bubble Tea Shop                      9
# New American Restaurant              9
# Concert Hall                         9
# Gym / Fitness Center                 9
# Office                               8
# Vietnamese Restaurant                8
# Lounge                               8
# Chinese Restaurant                   8
# Sporting Goods Shop                  8
# Salon / Barbershop                   8
# Fried Chicken Joint                  8
# Liquor Store                         7
# Plaza                                7
# Juice Bar                            7
# Cheese Shop                          7
# Indian Restaurant                    7
# Creperie                             7
# Middle Eastern Restaurant            7
# Music Venue                          6
# Comfort Food Restaurant              6
# Tea Room                             6
# Latin American Restaurant            6
# Museum                               5
# Nightclub                            5
# Shopping Mall                        5
# Food Court                           5
# Gay Bar                              5
# Gift Shop                            5
# Aquarium                             5
# Movie Theater                        5
# Tailor Shop                          5
# Spa                                  5
# Jazz Club                            5
# Fish Market                          5
# Speakeasy                            4
# Mediterranean Restaurant             4
# Gourmet Shop                         4
# Gluten-free Restaurant               4
# Poke Place                           4
# Hotel Bar                            4
# General Travel                       4
# Bagel Shop                           4
# Supermarket                          4
# Bistro                               4
# Distribution Center                  4
# Ramen Restaurant                     4
# Pet Store                            4
# Men's Store                          4
# Caribbean Restaurant                 4
# Electronics Store                    4
# Fountain                             4
# Monument / Landmark                  4
# Lingerie Store                       4
# Beer Store                           4
# Basketball Stadium                   4
# Donut Shop                           3
# Dog Run                              3
# Eastern European Restaurant          3
# Food Truck                           3
# Discount Store                       3
# Modern European Restaurant           3
# Scenic Lookout                       3
# Antique Shop                         3
# Miscellaneous Shop                   3
# Smoke Shop                           3
# Performing Arts Venue                3
# Comic Shop                           3
# Irish Pub                            3
# Smoothie Shop                        3
# BBQ Joint                            3
# Neighborhood                         3
# History Museum                       3
# Train Station                        3
# Noodle House                         3
# Fish & Chips Shop                    2
# Video Game Store                     2
# Butcher                              2
# Airport Lounge                       2
# Baseball Stadium                     2
# Falafel Restaurant                   2
# Event Space                          2
# Ethiopian Restaurant                 2
# Airport Service                      2
# Toy / Game Store                     2
# Candy Store                          2
# Dumpling Restaurant                  2
# Cuban Restaurant                     2
# Belgian Restaurant                   2
# Colombian Restaurant                 2
# Arts & Crafts Store                  2
# Convenience Store                    2
# Dance Studio                         2
# Art Museum                           2
# Cupcake Shop                         2
# Brazilian Restaurant                 2
# Shoe Store                           2
# Lake                                 2
# General Entertainment                2
# Hobby Shop                           2
# Historic Site                        2
# Moroccan Restaurant                  2
# Korean Restaurant                    2
# Snack Place                          2
# Playground                           2
# Indie Movie Theater                  2
# Portuguese Restaurant                2
# Poutine Place                        2
# IT Services                          2
# Record Shop                          2
# Market                               2
# Roof Deck                            2
# Light Rail Station                   2
# Sculpture Garden                     2
# Gaming Cafe                          2
# Massage Studio                       1
# Trail                                1
# Building                             1
# Malay Restaurant                     1
# Soup Place                           1
# Molecular Gastronomy Restaurant      1
# Boutique                             1
# Theme Restaurant                     1
# Boat or Ferry                        1
# Martial Arts School                  1
# Bowling Alley                        1
# Bed & Breakfast                      1
# Filipino Restaurant                  1
# Beach                                1
# Opera House                          1
# Airport                              1
# Airport Food Court                   1
# Airport Gate                         1
# Skate Park                           1
# Sake Bar                             1
# Airport Terminal                     1
# Skating Rink                         1
# Rental Car Location                  1
# Recording Studio                     1
# Athletics & Sports                   1
# Auto Workshop                        1
# Baby Store                           1
# Plane                                1
# Organic Grocery                      1
# Optical Shop                         1
# Other Great Outdoors                 1
# Kitchen Supply Store                 1
# Tanning Salon                        1
# Dive Bar                             1
# Harbor / Marina                      1
# Women's Store                        1
# Strip Club                           1
# Sports Bar                           1
# Stationery Store                     1
# Dim Sum Restaurant                   1
# Stadium                              1
# German Restaurant                    1
# Sri Lankan Restaurant                1
# Cajun / Creole Restaurant            1
# Doner Restaurant                     1
# Gas Station                          1
# Garden Center                        1
# Garden                               1
# Escape Room                          1
# Fruit & Vegetable Store              1
# Frozen Yogurt Shop                   1
# Food & Drink Shop                    1
# Health & Beauty Service              1
# Health Food Store                    1
# Coworking Space                      1
# Hookah Bar                           1
# Camera Store                         1
# Flea Market                          1
# Jewelry Store                        1
# Southern / Soul Food Restaurant      1
# Intersection                         1
# Chocolate Shop                       1
# Church                               1
# Climbing Gym                         1
# Taiwanese Restaurant                 1
# Indoor Play Area                     1
# College Arts Building                1
# College Auditorium                   1
# College Cafeteria                    1
# College Gym                          1
# College Rec Center                   1
# Hostel                               1
# Hospital                             1
# Afghan Restaurant                    1
# Name: Venue, dtype: int64

# %% [markdown]
# ### 2 main notes
#
# - The number of venues per neighbourhood is unbalanced (some areas have more venues than other). This is an issue for the clustering algorithm as the clusters will be created by checking how frequently a type of venues (category) is present in a neighbourhood. Areas with fewer venues will have much fewer factors that can be used by the algorithm to determine the optimal cluster
#
# - Although Venue Categories are unique, some of them are actually very related to each other (e.g. 'Pub' and 'Irish Pub'). Although semantlcally related, they will be treated as completely different entities by the clustering algorithm.

# %% [markdown]
# ## Prepare Neighbourhoods/Venues Dataset for the clustering algorithm

# %%
nearby_venues = nearby_venues.groupby(['Neighbourhood','Venue Category'])['Venue'].count().reset_index()

nearby_venues = nearby_venues.pivot(index='Neighbourhood', columns='Venue Category', values='Venue')
nearby_venues.fillna(0, inplace=True)

for i, row in nearby_venues.iterrows():
    nearby_venues.loc[i] = nearby_venues.loc[i]/np.sum(row)
    
nearby_venues.head()
# Out:
# Venue Category                                      Afghan Restaurant  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                       Airport  \
# Neighbourhood
# Berczy Park                                         0.000000
# Brockton, Parkdale Village, Exhibition Place        0.000000
# Business reply mail Processing Centre, South Ce...  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.058824
# Central Bay Street                                  0.000000
#
# Venue Category                                      Airport Food Court  \
# Neighbourhood
# Berczy Park                                                   0.000000
# Brockton, Parkdale Village, Exhibition Place                  0.000000
# Business reply mail Processing Centre, South Ce...            0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.058824
# Central Bay Street                                            0.000000
#
# Venue Category                                      Airport Gate  \
# Neighbourhood
# Berczy Park                                             0.000000
# Brockton, Parkdale Village, Exhibition Place            0.000000
# Business reply mail Processing Centre, South Ce...      0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...      0.058824
# Central Bay Street                                      0.000000
#
# Venue Category                                      Airport Lounge  \
# Neighbourhood
# Berczy Park                                               0.000000
# Brockton, Parkdale Village, Exhibition Place              0.000000
# Business reply mail Processing Centre, South Ce...        0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...        0.117647
# Central Bay Street                                        0.000000
#
# Venue Category                                      Airport Service  \
# Neighbourhood
# Berczy Park                                                0.000000
# Brockton, Parkdale Village, Exhibition Place               0.000000
# Business reply mail Processing Centre, South Ce...         0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...         0.117647
# Central Bay Street                                         0.000000
#
# Venue Category                                      Airport Terminal  \
# Neighbourhood
# Berczy Park                                                 0.000000
# Brockton, Parkdale Village, Exhibition Place                0.000000
# Business reply mail Processing Centre, South Ce...          0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.058824
# Central Bay Street                                          0.000000
#
# Venue Category                                      American Restaurant  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Antique Shop  Aquarium  \
# Neighbourhood
# Berczy Park                                                  0.0       0.0
# Brockton, Parkdale Village, Exhibition Place                 0.0       0.0
# Business reply mail Processing Centre, South Ce...           0.0       0.0
# CN Tower, King and Spadina, Railway Lands, Harb...           0.0       0.0
# Central Bay Street                                           0.0       0.0
#
# Venue Category                                      Art Gallery  Art Museum  \
# Neighbourhood
# Berczy Park                                            0.018182    0.000000
# Brockton, Parkdale Village, Exhibition Place           0.000000    0.000000
# Business reply mail Processing Centre, South Ce...     0.000000    0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000    0.000000
# Central Bay Street                                     0.000000    0.014706
#
# Venue Category                                      Arts & Crafts Store  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Asian Restaurant  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Athletics & Sports  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      Auto Workshop  BBQ Joint  \
# Neighbourhood
# Berczy Park                                                0.0000        0.0
# Brockton, Parkdale Village, Exhibition Place               0.0000        0.0
# Business reply mail Processing Centre, South Ce...         0.0625        0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0000        0.0
# Central Bay Street                                         0.0000        0.0
#
# Venue Category                                      Baby Store  Bagel Shop  \
# Neighbourhood
# Berczy Park                                                0.0    0.018182
# Brockton, Parkdale Village, Exhibition Place               0.0    0.000000
# Business reply mail Processing Centre, South Ce...         0.0    0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0    0.000000
# Central Bay Street                                         0.0    0.000000
#
# Venue Category                                        Bakery  Bank       Bar  \
# Neighbourhood
# Berczy Park                                         0.036364   0.0  0.000000
# Brockton, Parkdale Village, Exhibition Place        0.040000   0.0  0.040000
# Business reply mail Processing Centre, South Ce...  0.000000   0.0  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000   0.0  0.058824
# Central Bay Street                                  0.000000   0.0  0.000000
#
# Venue Category                                      Baseball Stadium  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Basketball Stadium  \
# Neighbourhood
# Berczy Park                                                   0.018182
# Brockton, Parkdale Village, Exhibition Place                  0.000000
# Business reply mail Processing Centre, South Ce...            0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.000000
# Central Bay Street                                            0.000000
#
# Venue Category                                         Beach  Bed & Breakfast  \
# Neighbourhood
# Berczy Park                                         0.018182              0.0
# Brockton, Parkdale Village, Exhibition Place        0.000000              0.0
# Business reply mail Processing Centre, South Ce...  0.000000              0.0
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000              0.0
# Central Bay Street                                  0.000000              0.0
#
# Venue Category                                      Beer Bar  Beer Store  \
# Neighbourhood
# Berczy Park                                         0.036364         0.0
# Brockton, Parkdale Village, Exhibition Place        0.000000         0.0
# Business reply mail Processing Centre, South Ce...  0.000000         0.0
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000         0.0
# Central Bay Street                                  0.000000         0.0
#
# Venue Category                                      Belgian Restaurant  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                        Bistro  Boat or Ferry  \
# Neighbourhood
# Berczy Park                                         0.018182       0.000000
# Brockton, Parkdale Village, Exhibition Place        0.000000       0.000000
# Business reply mail Processing Centre, South Ce...  0.000000       0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000       0.058824
# Central Bay Street                                  0.000000       0.000000
#
# Venue Category                                      Bookstore  Boutique  \
# Neighbourhood
# Berczy Park                                          0.000000  0.000000
# Brockton, Parkdale Village, Exhibition Place         0.040000  0.000000
# Business reply mail Processing Centre, South Ce...   0.000000  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...   0.000000  0.058824
# Central Bay Street                                   0.014706  0.000000
#
# Venue Category                                      Bowling Alley  \
# Neighbourhood
# Berczy Park                                                   0.0
# Brockton, Parkdale Village, Exhibition Place                  0.0
# Business reply mail Processing Centre, South Ce...            0.0
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0
# Central Bay Street                                            0.0
#
# Venue Category                                      Brazilian Restaurant  \
# Neighbourhood
# Berczy Park                                                          0.0
# Brockton, Parkdale Village, Exhibition Place                         0.0
# Business reply mail Processing Centre, South Ce...                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                   0.0
# Central Bay Street                                                   0.0
#
# Venue Category                                      Breakfast Spot  Brewery  \
# Neighbourhood
# Berczy Park                                               0.018182   0.0000
# Brockton, Parkdale Village, Exhibition Place              0.080000   0.0000
# Business reply mail Processing Centre, South Ce...        0.000000   0.0625
# CN Tower, King and Spadina, Railway Lands, Harb...        0.000000   0.0000
# Central Bay Street                                        0.000000   0.0000
#
# Venue Category                                      Bubble Tea Shop  Building  \
# Neighbourhood
# Berczy Park                                                0.000000       0.0
# Brockton, Parkdale Village, Exhibition Place               0.000000       0.0
# Business reply mail Processing Centre, South Ce...         0.000000       0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.000000       0.0
# Central Bay Street                                         0.029412       0.0
#
# Venue Category                                      Burger Joint  \
# Neighbourhood
# Berczy Park                                             0.000000
# Brockton, Parkdale Village, Exhibition Place            0.000000
# Business reply mail Processing Centre, South Ce...      0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...      0.000000
# Central Bay Street                                      0.029412
#
# Venue Category                                      Burrito Place  Butcher  \
# Neighbourhood
# Berczy Park                                                0.0000   0.0000
# Brockton, Parkdale Village, Exhibition Place               0.0400   0.0000
# Business reply mail Processing Centre, South Ce...         0.0625   0.0625
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0000   0.0000
# Central Bay Street                                         0.0000   0.0000
#
# Venue Category                                          Café  \
# Neighbourhood
# Berczy Park                                         0.018182
# Brockton, Parkdale Village, Exhibition Place        0.120000
# Business reply mail Processing Centre, South Ce...  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000
# Central Bay Street                                  0.058824
#
# Venue Category                                      Cajun / Creole Restaurant  \
# Neighbourhood
# Berczy Park                                                               0.0
# Brockton, Parkdale Village, Exhibition Place                              0.0
# Business reply mail Processing Centre, South Ce...                        0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                        0.0
# Central Bay Street                                                        0.0
#
# Venue Category                                      Camera Store  Candy Store  \
# Neighbourhood
# Berczy Park                                                  0.0          0.0
# Brockton, Parkdale Village, Exhibition Place                 0.0          0.0
# Business reply mail Processing Centre, South Ce...           0.0          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...           0.0          0.0
# Central Bay Street                                           0.0          0.0
#
# Venue Category                                      Caribbean Restaurant  \
# Neighbourhood
# Berczy Park                                                          0.0
# Brockton, Parkdale Village, Exhibition Place                         0.0
# Business reply mail Processing Centre, South Ce...                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                   0.0
# Central Bay Street                                                   0.0
#
# Venue Category                                      Cheese Shop  \
# Neighbourhood
# Berczy Park                                            0.036364
# Brockton, Parkdale Village, Exhibition Place           0.000000
# Business reply mail Processing Centre, South Ce...     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000
# Central Bay Street                                     0.000000
#
# Venue Category                                      Chinese Restaurant  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      Chocolate Shop  Church  \
# Neighbourhood
# Berczy Park                                                    0.0     0.0
# Brockton, Parkdale Village, Exhibition Place                   0.0     0.0
# Business reply mail Processing Centre, South Ce...             0.0     0.0
# CN Tower, King and Spadina, Railway Lands, Harb...             0.0     0.0
# Central Bay Street                                             0.0     0.0
#
# Venue Category                                      Climbing Gym  \
# Neighbourhood
# Berczy Park                                                 0.00
# Brockton, Parkdale Village, Exhibition Place                0.04
# Business reply mail Processing Centre, South Ce...          0.00
# CN Tower, King and Spadina, Railway Lands, Harb...          0.00
# Central Bay Street                                          0.00
#
# Venue Category                                      Clothing Store  \
# Neighbourhood
# Berczy Park                                                    0.0
# Brockton, Parkdale Village, Exhibition Place                   0.0
# Business reply mail Processing Centre, South Ce...             0.0
# CN Tower, King and Spadina, Railway Lands, Harb...             0.0
# Central Bay Street                                             0.0
#
# Venue Category                                      Cocktail Bar  Coffee Shop  \
# Neighbourhood
# Berczy Park                                             0.036364     0.090909
# Brockton, Parkdale Village, Exhibition Place            0.000000     0.080000
# Business reply mail Processing Centre, South Ce...      0.000000     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...      0.000000     0.058824
# Central Bay Street                                      0.000000     0.176471
#
# Venue Category                                      College Arts Building  \
# Neighbourhood
# Berczy Park                                                           0.0
# Brockton, Parkdale Village, Exhibition Place                          0.0
# Business reply mail Processing Centre, South Ce...                    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                    0.0
# Central Bay Street                                                    0.0
#
# Venue Category                                      College Auditorium  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      College Cafeteria  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                      College Gym  \
# Neighbourhood
# Berczy Park                                                 0.0
# Brockton, Parkdale Village, Exhibition Place                0.0
# Business reply mail Processing Centre, South Ce...          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0
# Central Bay Street                                          0.0
#
# Venue Category                                      College Rec Center  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      Colombian Restaurant  \
# Neighbourhood
# Berczy Park                                                          0.0
# Brockton, Parkdale Village, Exhibition Place                         0.0
# Business reply mail Processing Centre, South Ce...                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                   0.0
# Central Bay Street                                                   0.0
#
# Venue Category                                      Comfort Food Restaurant  \
# Neighbourhood
# Berczy Park                                                        0.018182
# Brockton, Parkdale Village, Exhibition Place                       0.000000
# Business reply mail Processing Centre, South Ce...                 0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.000000
# Central Bay Street                                                 0.000000
#
# Venue Category                                      Comic Shop  Concert Hall  \
# Neighbourhood
# Berczy Park                                           0.000000      0.018182
# Brockton, Parkdale Village, Exhibition Place          0.000000      0.000000
# Business reply mail Processing Centre, South Ce...    0.062500      0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...    0.000000      0.000000
# Central Bay Street                                    0.014706      0.000000
#
# Venue Category                                      Convenience Store  \
# Neighbourhood
# Berczy Park                                                      0.00
# Brockton, Parkdale Village, Exhibition Place                     0.04
# Business reply mail Processing Centre, South Ce...               0.00
# CN Tower, King and Spadina, Railway Lands, Harb...               0.00
# Central Bay Street                                               0.00
#
# Venue Category                                      Cosmetics Shop  \
# Neighbourhood
# Berczy Park                                                    0.0
# Brockton, Parkdale Village, Exhibition Place                   0.0
# Business reply mail Processing Centre, South Ce...             0.0
# CN Tower, King and Spadina, Railway Lands, Harb...             0.0
# Central Bay Street                                             0.0
#
# Venue Category                                      Coworking Space  Creperie  \
# Neighbourhood
# Berczy Park                                                     0.0  0.018182
# Brockton, Parkdale Village, Exhibition Place                    0.0  0.000000
# Business reply mail Processing Centre, South Ce...              0.0  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...              0.0  0.000000
# Central Bay Street                                              0.0  0.000000
#
# Venue Category                                      Cuban Restaurant  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Cupcake Shop  \
# Neighbourhood
# Berczy Park                                                  0.0
# Brockton, Parkdale Village, Exhibition Place                 0.0
# Business reply mail Processing Centre, South Ce...           0.0
# CN Tower, King and Spadina, Railway Lands, Harb...           0.0
# Central Bay Street                                           0.0
#
# Venue Category                                      Dance Studio  \
# Neighbourhood
# Berczy Park                                                  0.0
# Brockton, Parkdale Village, Exhibition Place                 0.0
# Business reply mail Processing Centre, South Ce...           0.0
# CN Tower, King and Spadina, Railway Lands, Harb...           0.0
# Central Bay Street                                           0.0
#
# Venue Category                                      Deli / Bodega  \
# Neighbourhood
# Berczy Park                                                   0.0
# Brockton, Parkdale Village, Exhibition Place                  0.0
# Business reply mail Processing Centre, South Ce...            0.0
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0
# Central Bay Street                                            0.0
#
# Venue Category                                      Department Store  \
# Neighbourhood
# Berczy Park                                                 0.018182
# Brockton, Parkdale Village, Exhibition Place                0.000000
# Business reply mail Processing Centre, South Ce...          0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.000000
# Central Bay Street                                          0.029412
#
# Venue Category                                      Dessert Shop  \
# Neighbourhood
# Berczy Park                                             0.000000
# Brockton, Parkdale Village, Exhibition Place            0.000000
# Business reply mail Processing Centre, South Ce...      0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...      0.000000
# Central Bay Street                                      0.014706
#
# Venue Category                                      Dim Sum Restaurant  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                         Diner  Discount Store  \
# Neighbourhood
# Berczy Park                                         0.018182        0.000000
# Brockton, Parkdale Village, Exhibition Place        0.000000        0.000000
# Business reply mail Processing Centre, South Ce...  0.000000        0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000        0.000000
# Central Bay Street                                  0.014706        0.014706
#
# Venue Category                                      Distribution Center  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Dive Bar  Dog Run  \
# Neighbourhood
# Berczy Park                                              0.0      0.0
# Brockton, Parkdale Village, Exhibition Place             0.0      0.0
# Business reply mail Processing Centre, South Ce...       0.0      0.0
# CN Tower, King and Spadina, Railway Lands, Harb...       0.0      0.0
# Central Bay Street                                       0.0      0.0
#
# Venue Category                                      Doner Restaurant  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Donut Shop  \
# Neighbourhood
# Berczy Park                                           0.000000
# Brockton, Parkdale Village, Exhibition Place          0.000000
# Business reply mail Processing Centre, South Ce...    0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...    0.000000
# Central Bay Street                                    0.014706
#
# Venue Category                                      Dumpling Restaurant  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Eastern European Restaurant  \
# Neighbourhood
# Berczy Park                                                            0.018182
# Brockton, Parkdale Village, Exhibition Place                           0.000000
# Business reply mail Processing Centre, South Ce...                     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...                     0.000000
# Central Bay Street                                                     0.000000
#
# Venue Category                                      Electronics Store  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                      Escape Room  \
# Neighbourhood
# Berczy Park                                                 0.0
# Brockton, Parkdale Village, Exhibition Place                0.0
# Business reply mail Processing Centre, South Ce...          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0
# Central Bay Street                                          0.0
#
# Venue Category                                      Ethiopian Restaurant  \
# Neighbourhood
# Berczy Park                                                          0.0
# Brockton, Parkdale Village, Exhibition Place                         0.0
# Business reply mail Processing Centre, South Ce...                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                   0.0
# Central Bay Street                                                   0.0
#
# Venue Category                                      Event Space  \
# Neighbourhood
# Berczy Park                                                 0.0
# Brockton, Parkdale Village, Exhibition Place                0.0
# Business reply mail Processing Centre, South Ce...          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0
# Central Bay Street                                          0.0
#
# Venue Category                                      Falafel Restaurant  \
# Neighbourhood
# Berczy Park                                                   0.000000
# Brockton, Parkdale Village, Exhibition Place                  0.000000
# Business reply mail Processing Centre, South Ce...            0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.000000
# Central Bay Street                                            0.014706
#
# Venue Category                                      Farmers Market  \
# Neighbourhood
# Berczy Park                                               0.036364
# Brockton, Parkdale Village, Exhibition Place              0.000000
# Business reply mail Processing Centre, South Ce...        0.062500
# CN Tower, King and Spadina, Railway Lands, Harb...        0.000000
# Central Bay Street                                        0.000000
#
# Venue Category                                      Fast Food Restaurant  \
# Neighbourhood
# Berczy Park                                                       0.0000
# Brockton, Parkdale Village, Exhibition Place                      0.0000
# Business reply mail Processing Centre, South Ce...                0.0625
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0000
# Central Bay Street                                                0.0000
#
# Venue Category                                      Filipino Restaurant  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Fish & Chips Shop  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                      Fish Market  Flea Market  \
# Neighbourhood
# Berczy Park                                            0.018182          0.0
# Brockton, Parkdale Village, Exhibition Place           0.000000          0.0
# Business reply mail Processing Centre, South Ce...     0.000000          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000          0.0
# Central Bay Street                                     0.000000          0.0
#
# Venue Category                                      Food & Drink Shop  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                      Food Court  Food Truck  \
# Neighbourhood
# Berczy Park                                                0.0         0.0
# Brockton, Parkdale Village, Exhibition Place               0.0         0.0
# Business reply mail Processing Centre, South Ce...         0.0         0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0         0.0
# Central Bay Street                                         0.0         0.0
#
# Venue Category                                      Fountain  \
# Neighbourhood
# Berczy Park                                         0.018182
# Brockton, Parkdale Village, Exhibition Place        0.000000
# Business reply mail Processing Centre, South Ce...  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000
# Central Bay Street                                  0.000000
#
# Venue Category                                      French Restaurant  \
# Neighbourhood
# Berczy Park                                                  0.018182
# Brockton, Parkdale Village, Exhibition Place                 0.000000
# Business reply mail Processing Centre, South Ce...           0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...           0.000000
# Central Bay Street                                           0.014706
#
# Venue Category                                      Fried Chicken Joint  \
# Neighbourhood
# Berczy Park                                                         0.0
# Brockton, Parkdale Village, Exhibition Place                        0.0
# Business reply mail Processing Centre, South Ce...                  0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                  0.0
# Central Bay Street                                                  0.0
#
# Venue Category                                      Frozen Yogurt Shop  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      Fruit & Vegetable Store  \
# Neighbourhood
# Berczy Park                                                             0.0
# Brockton, Parkdale Village, Exhibition Place                            0.0
# Business reply mail Processing Centre, South Ce...                      0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                      0.0
# Central Bay Street                                                      0.0
#
# Venue Category                                      Furniture / Home Store  \
# Neighbourhood
# Berczy Park                                                       0.000000
# Brockton, Parkdale Village, Exhibition Place                      0.040000
# Business reply mail Processing Centre, South Ce...                0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...                0.000000
# Central Bay Street                                                0.014706
#
# Venue Category                                      Gaming Cafe  Garden  \
# Neighbourhood
# Berczy Park                                                 0.0  0.0000
# Brockton, Parkdale Village, Exhibition Place                0.0  0.0000
# Business reply mail Processing Centre, South Ce...          0.0  0.0625
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0  0.0000
# Central Bay Street                                          0.0  0.0000
#
# Venue Category                                      Garden Center  \
# Neighbourhood
# Berczy Park                                                0.0000
# Brockton, Parkdale Village, Exhibition Place               0.0000
# Business reply mail Processing Centre, South Ce...         0.0625
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0000
# Central Bay Street                                         0.0000
#
# Venue Category                                      Gas Station  Gastropub  \
# Neighbourhood
# Berczy Park                                                 0.0   0.000000
# Brockton, Parkdale Village, Exhibition Place                0.0   0.000000
# Business reply mail Processing Centre, South Ce...          0.0   0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0   0.000000
# Central Bay Street                                          0.0   0.014706
#
# Venue Category                                      Gay Bar  \
# Neighbourhood
# Berczy Park                                             0.0
# Brockton, Parkdale Village, Exhibition Place            0.0
# Business reply mail Processing Centre, South Ce...      0.0
# CN Tower, King and Spadina, Railway Lands, Harb...      0.0
# Central Bay Street                                      0.0
#
# Venue Category                                      General Entertainment  \
# Neighbourhood
# Berczy Park                                                           0.0
# Brockton, Parkdale Village, Exhibition Place                          0.0
# Business reply mail Processing Centre, South Ce...                    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                    0.0
# Central Bay Street                                                    0.0
#
# Venue Category                                      General Travel  \
# Neighbourhood
# Berczy Park                                                    0.0
# Brockton, Parkdale Village, Exhibition Place                   0.0
# Business reply mail Processing Centre, South Ce...             0.0
# CN Tower, King and Spadina, Railway Lands, Harb...             0.0
# Central Bay Street                                             0.0
#
# Venue Category                                      German Restaurant  \
# Neighbourhood
# Berczy Park                                                       0.0
# Brockton, Parkdale Village, Exhibition Place                      0.0
# Business reply mail Processing Centre, South Ce...                0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                0.0
# Central Bay Street                                                0.0
#
# Venue Category                                      Gift Shop  \
# Neighbourhood
# Berczy Park                                               0.0
# Brockton, Parkdale Village, Exhibition Place              0.0
# Business reply mail Processing Centre, South Ce...        0.0
# CN Tower, King and Spadina, Railway Lands, Harb...        0.0
# Central Bay Street                                        0.0
#
# Venue Category                                      Gluten-free Restaurant  \
# Neighbourhood
# Berczy Park                                                            0.0
# Brockton, Parkdale Village, Exhibition Place                           0.0
# Business reply mail Processing Centre, South Ce...                     0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                     0.0
# Central Bay Street                                                     0.0
#
# Venue Category                                      Gourmet Shop  \
# Neighbourhood
# Berczy Park                                             0.018182
# Brockton, Parkdale Village, Exhibition Place            0.000000
# Business reply mail Processing Centre, South Ce...      0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...      0.000000
# Central Bay Street                                      0.000000
#
# Venue Category                                      Greek Restaurant  \
# Neighbourhood
# Berczy Park                                                 0.018182
# Brockton, Parkdale Village, Exhibition Place                0.000000
# Business reply mail Processing Centre, South Ce...          0.000000
# ...
# Central Bay Street                                       0.0     0.029412
#
# Venue Category                                      Salon / Barbershop  \
# Neighbourhood
# Berczy Park                                                        0.0
# Brockton, Parkdale Village, Exhibition Place                       0.0
# Business reply mail Processing Centre, South Ce...                 0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                 0.0
# Central Bay Street                                                 0.0
#
# Venue Category                                      Sandwich Place  \
# Neighbourhood
# Berczy Park                                               0.018182
# Brockton, Parkdale Village, Exhibition Place              0.000000
# Business reply mail Processing Centre, South Ce...        0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...        0.000000
# Central Bay Street                                        0.044118
#
# Venue Category                                      Scenic Lookout  \
# Neighbourhood
# Berczy Park                                                    0.0
# Brockton, Parkdale Village, Exhibition Place                   0.0
# Business reply mail Processing Centre, South Ce...             0.0
# CN Tower, King and Spadina, Railway Lands, Harb...             0.0
# Central Bay Street                                             0.0
#
# Venue Category                                      Sculpture Garden  \
# Neighbourhood
# Berczy Park                                                 0.000000
# Brockton, Parkdale Village, Exhibition Place                0.000000
# Business reply mail Processing Centre, South Ce...          0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.058824
# Central Bay Street                                          0.000000
#
# Venue Category                                      Seafood Restaurant  \
# Neighbourhood
# Berczy Park                                                   0.036364
# Brockton, Parkdale Village, Exhibition Place                  0.000000
# Business reply mail Processing Centre, South Ce...            0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.000000
# Central Bay Street                                            0.014706
#
# Venue Category                                      Shoe Store  Shopping Mall  \
# Neighbourhood
# Berczy Park                                                0.0       0.018182
# Brockton, Parkdale Village, Exhibition Place               0.0       0.000000
# Business reply mail Processing Centre, South Ce...         0.0       0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0       0.000000
# Central Bay Street                                         0.0       0.000000
#
# Venue Category                                      Skate Park  Skating Rink  \
# Neighbourhood
# Berczy Park                                             0.0000           0.0
# Brockton, Parkdale Village, Exhibition Place            0.0000           0.0
# Business reply mail Processing Centre, South Ce...      0.0625           0.0
# CN Tower, King and Spadina, Railway Lands, Harb...      0.0000           0.0
# Central Bay Street                                      0.0000           0.0
#
# Venue Category                                      Smoke Shop  Smoothie Shop  \
# Neighbourhood
# Berczy Park                                                0.0            0.0
# Brockton, Parkdale Village, Exhibition Place               0.0            0.0
# Business reply mail Processing Centre, South Ce...         0.0            0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0            0.0
# Central Bay Street                                         0.0            0.0
#
# Venue Category                                      Snack Place  Soup Place  \
# Neighbourhood
# Berczy Park                                                 0.0         0.0
# Brockton, Parkdale Village, Exhibition Place                0.0         0.0
# Business reply mail Processing Centre, South Ce...          0.0         0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0         0.0
# Central Bay Street                                          0.0         0.0
#
# Venue Category                                      Southern / Soul Food Restaurant  \
# Neighbourhood
# Berczy Park                                                                     0.0
# Brockton, Parkdale Village, Exhibition Place                                    0.0
# Business reply mail Processing Centre, South Ce...                              0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                              0.0
# Central Bay Street                                                              0.0
#
# Venue Category                                           Spa  Speakeasy  \
# Neighbourhood
# Berczy Park                                         0.000000        0.0
# Brockton, Parkdale Village, Exhibition Place        0.000000        0.0
# Business reply mail Processing Centre, South Ce...  0.000000        0.0
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000        0.0
# Central Bay Street                                  0.014706        0.0
#
# Venue Category                                      Sporting Goods Shop  \
# Neighbourhood
# Berczy Park                                                    0.018182
# Brockton, Parkdale Village, Exhibition Place                   0.000000
# Business reply mail Processing Centre, South Ce...             0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...             0.000000
# Central Bay Street                                             0.000000
#
# Venue Category                                      Sports Bar  \
# Neighbourhood
# Berczy Park                                                0.0
# Brockton, Parkdale Village, Exhibition Place               0.0
# Business reply mail Processing Centre, South Ce...         0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.0
# Central Bay Street                                         0.0
#
# Venue Category                                      Sri Lankan Restaurant  \
# Neighbourhood
# Berczy Park                                                           0.0
# Brockton, Parkdale Village, Exhibition Place                          0.0
# Business reply mail Processing Centre, South Ce...                    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                    0.0
# Central Bay Street                                                    0.0
#
# Venue Category                                      Stadium  Stationery Store  \
# Neighbourhood
# Berczy Park                                            0.00               0.0
# Brockton, Parkdale Village, Exhibition Place           0.04               0.0
# Business reply mail Processing Centre, South Ce...     0.00               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...     0.00               0.0
# Central Bay Street                                     0.00               0.0
#
# Venue Category                                      Steakhouse  Strip Club  \
# Neighbourhood
# Berczy Park                                           0.018182         0.0
# Brockton, Parkdale Village, Exhibition Place          0.000000         0.0
# Business reply mail Processing Centre, South Ce...    0.000000         0.0
# CN Tower, King and Spadina, Railway Lands, Harb...    0.000000         0.0
# Central Bay Street                                    0.000000         0.0
#
# Venue Category                                      Supermarket  \
# Neighbourhood
# Berczy Park                                                 0.0
# Brockton, Parkdale Village, Exhibition Place                0.0
# Business reply mail Processing Centre, South Ce...          0.0
# CN Tower, King and Spadina, Railway Lands, Harb...          0.0
# Central Bay Street                                          0.0
#
# Venue Category                                      Sushi Restaurant  \
# Neighbourhood
# Berczy Park                                                 0.018182
# Brockton, Parkdale Village, Exhibition Place                0.000000
# Business reply mail Processing Centre, South Ce...          0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...          0.000000
# Central Bay Street                                          0.014706
#
# Venue Category                                      Tailor Shop  \
# Neighbourhood
# Berczy Park                                            0.018182
# Brockton, Parkdale Village, Exhibition Place           0.000000
# Business reply mail Processing Centre, South Ce...     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000
# Central Bay Street                                     0.000000
#
# Venue Category                                      Taiwanese Restaurant  \
# Neighbourhood
# Berczy Park                                                          0.0
# Brockton, Parkdale Village, Exhibition Place                         0.0
# Business reply mail Processing Centre, South Ce...                   0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                   0.0
# Central Bay Street                                                   0.0
#
# Venue Category                                      Tanning Salon  Tea Room  \
# Neighbourhood
# Berczy Park                                                   0.0  0.000000
# Brockton, Parkdale Village, Exhibition Place                  0.0  0.000000
# Business reply mail Processing Centre, South Ce...            0.0  0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0  0.000000
# Central Bay Street                                            0.0  0.014706
#
# Venue Category                                      Thai Restaurant  Theater  \
# Neighbourhood
# Berczy Park                                                0.018182      0.0
# Brockton, Parkdale Village, Exhibition Place               0.000000      0.0
# Business reply mail Processing Centre, South Ce...         0.000000      0.0
# CN Tower, King and Spadina, Railway Lands, Harb...         0.000000      0.0
# Central Bay Street                                         0.029412      0.0
#
# Venue Category                                      Theme Restaurant  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Toy / Game Store  Trail  \
# Neighbourhood
# Berczy Park                                                      0.0    0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0    0.0
# Business reply mail Processing Centre, South Ce...               0.0    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0    0.0
# Central Bay Street                                               0.0    0.0
#
# Venue Category                                      Train Station  \
# Neighbourhood
# Berczy Park                                                   0.0
# Brockton, Parkdale Village, Exhibition Place                  0.0
# Business reply mail Processing Centre, South Ce...            0.0
# CN Tower, King and Spadina, Railway Lands, Harb...            0.0
# Central Bay Street                                            0.0
#
# Venue Category                                      Vegetarian / Vegan Restaurant  \
# Neighbourhood
# Berczy Park                                                              0.018182
# Brockton, Parkdale Village, Exhibition Place                             0.000000
# Business reply mail Processing Centre, South Ce...                       0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...                       0.000000
# Central Bay Street                                                       0.014706
#
# Venue Category                                      Video Game Store  \
# Neighbourhood
# Berczy Park                                                      0.0
# Brockton, Parkdale Village, Exhibition Place                     0.0
# Business reply mail Processing Centre, South Ce...               0.0
# CN Tower, King and Spadina, Railway Lands, Harb...               0.0
# Central Bay Street                                               0.0
#
# Venue Category                                      Vietnamese Restaurant  \
# Neighbourhood
# Berczy Park                                                           0.0
# Brockton, Parkdale Village, Exhibition Place                          0.0
# Business reply mail Processing Centre, South Ce...                    0.0
# CN Tower, King and Spadina, Railway Lands, Harb...                    0.0
# Central Bay Street                                                    0.0
#
# Venue Category                                      Wine Bar  Women's Store  \
# Neighbourhood
# Berczy Park                                         0.000000            0.0
# Brockton, Parkdale Village, Exhibition Place        0.000000            0.0
# Business reply mail Processing Centre, South Ce...  0.000000            0.0
# CN Tower, King and Spadina, Railway Lands, Harb...  0.000000            0.0
# Central Bay Street                                  0.014706            0.0
#
# Venue Category                                      Yoga Studio
# Neighbourhood
# Berczy Park                                            0.000000
# Brockton, Parkdale Village, Exhibition Place           0.000000
# Business reply mail Processing Centre, South Ce...     0.000000
# CN Tower, King and Spadina, Railway Lands, Harb...     0.000000
# Central Bay Street                                     0.014706

# %% [markdown]
# ## Clustering algorithm

# %%
kclusters = 2
kmeans = KMeans(n_clusters=kclusters, n_init=10).fit(nearby_venues)

nearby_venues['Cluster Labels'] = kmeans.labels_
locations_venues = target_locations.set_index('Neighbourhood').join(nearby_venues['Cluster Labels'], on='Neighbourhood', how='inner')

# %% [markdown]
# ## Exploring the Clusters

# %% [markdown]
# #### Cluster Density:

# %%
locations_venues['Cluster Labels'].value_counts()
# Out:
# 0    26
# 1     6
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# #### Clusters Composition:

# %%
Cluster_nr = 1
pd.DataFrame({'frequency':nearby_venues.groupby(['Cluster Labels']).mean().loc[Cluster_nr-1].sort_values(ascending=False)[1:10]})
# Out:
#                     frequency
# Venue Category
# Café                 0.038958
# Restaurant           0.037783
# Italian Restaurant   0.023962
# Park                 0.023328
# Pizza Place          0.022568
# Sushi Restaurant     0.018065
# Bar                  0.017583
# Hotel                0.016406
# Pub                  0.016027

# %% [markdown]
# Cluster 1 seems to be an office/business - afterwork/nightlife cluster. Its neighbourhoods are very central.

# %%
Cluster_nr = 2
pd.DataFrame({'frequency':nearby_venues.groupby(['Cluster Labels']).mean().loc[Cluster_nr-1].sort_values(ascending=False)[1:10]})
# Out:
#                     frequency
# Venue Category
# Grocery Store        0.067564
# Park                 0.048836
# Bakery               0.048522
# Coffee Shop          0.046196
# Bar                  0.042112
# Sandwich Place       0.036120
# Pharmacy             0.034413
# Nightclub            0.028652
# Italian Restaurant   0.028396

# %% [markdown]
# Cluster 2 seems to be a residential cluster. Its neighbourhoods are slighly far off from the city centre.

# %% [markdown]
# ## Create map with Clusters

# %%
location = 'Toronto, Ontario, Canada'
map_centre = Nominatim(user_agent="ny_explorer").geocode(location)

map_clusters = folium.Map(location=[map_centre.latitude,
                                   map_centre.longitude],
                          tiles = 'Stamen Terrain',
                         zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
    
for name, row in locations_venues.iterrows():

    label = folium.Popup(str(name) + ' Cluster ' + str(row['Cluster Labels']), parse_html=True)
    folium.CircleMarker([row['Latitude'], row['Longitude']],
                        radius=5,
                        popup=label,
                        color=rainbow[row['Cluster Labels']-1],
                        fill=True,
                        fill_color=rainbow[row['Cluster Labels']-1],
                        fill_opacity=0.7).add_to(map_clusters)

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
